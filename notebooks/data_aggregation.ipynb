# %%
# Importing Libraries
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# # Reading the basic dataset
#
# The _military-hollywood-full_imdbidAdded.csv_ contains the rows of movies that US DOD has supported. The data has 7 columns.
#
# |Column name | Description |
# | :-:        | -:-:    |
# |Title|The title of the film or TV show requesting assistance.|
# |Subtitle|An alternate name for the film, or the episode title of the TV show.|
# |Status| The military's response to the assistance request.|
# |Media Type| The type of media requesting assistance, a Film or TV show.|
# |Year| The year that the film or TV episode was released.|
# |Remarks| A description of the request from the military's perspective.|
#
#
# **Note:** This is not an exhaustive list, it only contains the movies list that DoD has choose to release.

# %%
# reading the basic dataset
dod_movies = pd.read_csv("./../primary_data/military-hollywood-full_imdbidAdded.csv")
dod_movies
# Out:
#                              Title     IMDB_ID       Subtitle Status  \
# 0                           "1968"  Never Made            NaN    OTH
# 1             1,000 MEN AND A BABY   tt0133231            NaN    APP
# 2                        1ST FORCE  Never Made            NaN    OTH
# 3                               24   tt0502209             22    APP
# 4                       3RD DEGREE   tt0098469            NaN    APP
# ..                             ...         ...            ...    ...
# 852              WONDER YEARS, THE   tt0094582          ANGEL    LIM
# 853                           X-15   tt0055627            NaN    APP
# 854            YEAR IN THE LIFE, A   tt0092488  ACTS OF FAITH    DEN
# 855               YOUNG LIONS, THE   tt0052415            NaN    APP
# 856  YOUR MOMMA WEARS COMBAT BOOTS   tt0098696            NaN    APP
#
#     Media Type    Year                                            Remarks
# 0         FILM     NaN  THE FILM STARTED OUT VERY NEGATIVE FOR THE ARM...
# 1           TV  1997.0  VERY POSITIVE DEPICTION OF NAVY IN THIS KOREAN...
# 2         FILM     NaN  INITIALLY DOD AND USMC WERE INCLINED TO SUPPOR...
# 3           TV  2004.0  APPROVED FILMING FOR ONE DAY WITH TWO MARINE C...
# 4           TV  1989.0  PERSONNEL APPEARED ON THIS GAME SHOW AT THE EX...
# ..         ...     ...                                                ...
# 852         TV  1988.0  THE UNITED STATES AIR FORCE GRANTED STOCK FOOT...
# 853       FILM  1961.0  AIRFORCE AND NASA PROVIDED FULL COOPERATION ON...
# 854         TV  1987.0                 THE PROJECT WAS DENIED ASSISTANCE.
# 855       FILM  1958.0  PENTAGON AND STATE DEPARTMENT WENT THROUGH LON...
# 856         TV  1989.0  ARMY AND AIR FORCE ASSISTANCE WAS GRANTED. THE...
#
# [857 rows x 7 columns]

# %% [markdown]
# ### Remarks on the basic dataset.
#
# For the movies that were not produced, the IMDB ID is Never made and for the movies we were not able to find online the IMDB ID is left empty.
#
# The Year column is currently filled using the data from the offical document released by the US [Department of Defence](https://drive.google.com/file/d/1NeDVYu_gvEhtdQVtSFPRIapHDxJx6842/view). Later, we shall update it from the IMDB data.
#
# The subtitle is NaN for most cases and contains previous name in case of films and episode name in case of TV series.
#
# In the status column, APP means the assistance was approved by US DoD, DEN means it was denied. LIM means only limited assistance was provided. OTH mean either the film did not request the assistance or has withdrew the request. RSCH means only research assistance was provided.

# %% [markdown]
# # Additional Data
#
# Now, we source and append the following additional data to the above data frame: Year, Release Date, Directors, Plot, Awards, Runtime, IMDB Ratings and generes. This data is obtained from [OMDB API](http://www.omdbapi.com/).
#
# The steps involved are
# 1. Provide the API key and parameter to get full plot.
# 2. Check if there is a response or not, as some movies are not existing.
# 3. For the movies that have a response, we collected the required data and return it.
# 4. Then we shall replace the old year column with new year column and append the remaining columns.

# %%
def get_movie_additional_data(imdb_id, curr_year):
    """
    Function to obtain the additional data of the movie such as Year, Release Date, Directors, Plot, Awards, Runtime, IMDB Ratings and generes.

    :param imdb_id(str): The IMDB id of the movie
    :param curr_year(str): The year of release of the movie according to the basic dataset.
    :return addl_data(List): The additional data as a list with elements in the following order [year, genre, runtime, director, plot, award, imdb_rating, release_date]
    """
    # obtaining additional data from OMDB API

    params = {'plot': 'full'}
    apiKey = '7d4700e0'  #  OMDB api key here

    try:
        data_URL = 'http://www.omdbapi.com/?i='+imdb_id+'&apikey='+apiKey
        response = requests.get(data_URL, params=params).json()
    except:
        response = {}

    year = response.get("Year", curr_year)
    if "–" in str(year):
        # In case of tv series, where the episode is not identified, we get the year as an range.
        # In that case, we shall the use the Year provided in the basic dataset.
        year = curr_year
    genre = response.get("Genre")
    runtime = response.get("Runtime")
    director = response.get("Director")
    plot = response.get("Plot")
    award = response.get("Awards")
    imdb_rating = response.get("imdbRating")
    release_date = response.get("Released")

    return [year, genre, runtime, director, plot, award, imdb_rating, release_date]

# %%
additional_movie_data = dod_movies.apply(lambda row: get_movie_additional_data(row.IMDB_ID, row.Year), axis='columns', result_type='expand')
additional_movie_data.columns = ["Year_omdb", "genre", "runtime", "director", "plot", "award", "imdb_rating", "release_date"]
dod_movies_with_addl_data = pd.concat([dod_movies, additional_movie_data], axis='columns')
dod_movies_with_addl_data.drop(columns='Year', inplace=True)
dod_movies_with_addl_data.rename(columns={"Year_omdb":"Year"}, inplace=True)
dod_movies_with_addl_data
# Out:
#                              Title     IMDB_ID       Subtitle Status  \
# 0                           "1968"  Never Made            NaN    OTH
# 1             1,000 MEN AND A BABY   tt0133231            NaN    APP
# 2                        1ST FORCE  Never Made            NaN    OTH
# 3                               24   tt0502209             22    APP
# 4                       3RD DEGREE   tt0098469            NaN    APP
# ..                             ...         ...            ...    ...
# 852              WONDER YEARS, THE   tt0094582          ANGEL    LIM
# 853                           X-15   tt0055627            NaN    APP
# 854            YEAR IN THE LIFE, A   tt0092488  ACTS OF FAITH    DEN
# 855               YOUNG LIONS, THE   tt0052415            NaN    APP
# 856  YOUR MOMMA WEARS COMBAT BOOTS   tt0098696            NaN    APP
#
#     Media Type                                            Remarks  Year  \
# 0         FILM  THE FILM STARTED OUT VERY NEGATIVE FOR THE ARM...   NaN
# 1           TV  VERY POSITIVE DEPICTION OF NAVY IN THIS KOREAN...  1997
# 2         FILM  INITIALLY DOD AND USMC WERE INCLINED TO SUPPOR...   NaN
# 3           TV  APPROVED FILMING FOR ONE DAY WITH TWO MARINE C...  2004
# 4           TV  PERSONNEL APPEARED ON THIS GAME SHOW AT THE EX...  1989
# ..         ...                                                ...   ...
# 852         TV  THE UNITED STATES AIR FORCE GRANTED STOCK FOOT...  1988
# 853       FILM  AIRFORCE AND NASA PROVIDED FULL COOPERATION ON...  1961
# 854         TV                 THE PROJECT WAS DENIED ASSISTANCE.  1987
# 855       FILM  PENTAGON AND STATE DEPARTMENT WENT THROUGH LON...  1958
# 856         TV  ARMY AND AIR FORCE ASSISTANCE WAS GRANTED. THE...  1989
#
#                               genre  runtime               director  \
# 0                               NaN      NaN                    NaN
# 1                             Drama   96 min            Marcus Cole
# 2                               NaN      NaN                    NaN
# 3    Action, Crime, Drama, Thriller   42 min  Frederick King Keller
# 4            Crime, Drama, Thriller  100 min     Roger Spottiswoode
# ..                              ...      ...                    ...
# 852  Comedy, Drama, Family, Romance   22 min                    N/A
# 853                  Drama, History  107 min         Richard Donner
# 854                           Drama   60 min                    N/A
# 855              Action, Drama, War  167 min         Edward Dmytryk
# 856                          Comedy  100 min         Anson Williams
#
#                                                   plot  \
# 0                                                  NaN
# 1    A baby in a foreign land is adopted by the men...
# 2                                                  NaN
# 3    Jack and Tony clash as they wait for the time ...
# 4    Scott Weston is a private investigator who is ...
# ..                                                 ...
# 852  An adult Kevin Arnold reminisces on his teenag...
# 853  At the height of the Cold War during the 1960s...
# 854  Joe Gardner, a child of the Depression, is a s...
# 855  The destiny of three soldiers during World War...
# 856  An overprotective single mother tries to stop ...
#
#                                                  award imdb_rating  \
# 0                                                  NaN         NaN
# 1                                                  N/A         6.9
# 2                                                  NaN         NaN
# 3                                                  N/A         9.0
# 4                                                  N/A         5.7
# ..                                                 ...         ...
# 852  Won 1 Golden Globe. Another 24 wins & 70 nomin...         8.3
# 853                                                N/A         5.8
# 854  Won 1 Golden Globe. Another 3 wins & 3 nominat...         8.8
# 855  Nominated for 3 Oscars. Another 1 win & 4 nomi...         7.2
# 856                                                N/A         5.6
#
#     release_date
# 0            NaN
# 1    07 Dec 1997
# 2            NaN
# 3    11 May 2004
# 4    28 May 1989
# ..           ...
# 852  31 Jan 1988
# 853  22 Dec 1961
# 854  16 Sep 1987
# 855  02 Apr 1958
# 856  27 Mar 1989
#
# [857 rows x 14 columns]

# %% [markdown]
# ### Remarks on the updated dataset
#
# We see that certain values in the columns are 'N/A' obtained from the OMDB API. Thus we shall replace them with NaN.

# %%
dod_movies_with_addl_data.replace(regex={'N/A': np.nan}, inplace=True)

# %% [markdown]
# We see that dates(year and release data) values in the columns are strings and integers. Thus we shall convert them into datetime.

# %%
dod_movies_with_addl_data['release_date'] = pd.to_datetime(dod_movies_with_addl_data['release_date'], errors='ignore', format='%Y%m%d')
dod_movies_with_addl_data['Year'] = pd.to_datetime(dod_movies_with_addl_data['Year'], errors='ignore', format='%Y')

# %%
dod_movies_with_addl_data
# Out:
#                              Title     IMDB_ID       Subtitle Status  \
# 0                           "1968"  Never Made            NaN    OTH
# 1             1,000 MEN AND A BABY   tt0133231            NaN    APP
# 2                        1ST FORCE  Never Made            NaN    OTH
# 3                               24   tt0502209             22    APP
# 4                       3RD DEGREE   tt0098469            NaN    APP
# ..                             ...         ...            ...    ...
# 852              WONDER YEARS, THE   tt0094582          ANGEL    LIM
# 853                           X-15   tt0055627            NaN    APP
# 854            YEAR IN THE LIFE, A   tt0092488  ACTS OF FAITH    DEN
# 855               YOUNG LIONS, THE   tt0052415            NaN    APP
# 856  YOUR MOMMA WEARS COMBAT BOOTS   tt0098696            NaN    APP
#
#     Media Type                                            Remarks  Year  \
# 0         FILM  THE FILM STARTED OUT VERY NEGATIVE FOR THE ARM...   NaN
# 1           TV  VERY POSITIVE DEPICTION OF NAVY IN THIS KOREAN...  1997
# 2         FILM  INITIALLY DOD AND USMC WERE INCLINED TO SUPPOR...   NaN
# 3           TV  APPROVED FILMING FOR ONE DAY WITH TWO MARINE C...  2004
# 4           TV  PERSONNEL APPEARED ON THIS GAME SHOW AT THE EX...  1989
# ..         ...                                                ...   ...
# 852         TV  THE UNITED STATES AIR FORCE GRANTED STOCK FOOT...  1988
# 853       FILM  AIRFORCE AND NASA PROVIDED FULL COOPERATION ON...  1961
# 854         TV                 THE PROJECT WAS DENIED ASSISTANCE.  1987
# 855       FILM  PENTAGON AND STATE DEPARTMENT WENT THROUGH LON...  1958
# 856         TV  ARMY AND AIR FORCE ASSISTANCE WAS GRANTED. THE...  1989
#
#                               genre  runtime               director  \
# 0                               NaN      NaN                    NaN
# 1                             Drama   96 min            Marcus Cole
# 2                               NaN      NaN                    NaN
# 3    Action, Crime, Drama, Thriller   42 min  Frederick King Keller
# 4            Crime, Drama, Thriller  100 min     Roger Spottiswoode
# ..                              ...      ...                    ...
# 852  Comedy, Drama, Family, Romance   22 min                    NaN
# 853                  Drama, History  107 min         Richard Donner
# 854                           Drama   60 min                    NaN
# 855              Action, Drama, War  167 min         Edward Dmytryk
# 856                          Comedy  100 min         Anson Williams
#
#                                                   plot  \
# 0                                                  NaN
# 1    A baby in a foreign land is adopted by the men...
# 2                                                  NaN
# 3    Jack and Tony clash as they wait for the time ...
# 4    Scott Weston is a private investigator who is ...
# ..                                                 ...
# 852  An adult Kevin Arnold reminisces on his teenag...
# 853  At the height of the Cold War during the 1960s...
# 854  Joe Gardner, a child of the Depression, is a s...
# 855  The destiny of three soldiers during World War...
# 856  An overprotective single mother tries to stop ...
#
#                                                  award imdb_rating  \
# 0                                                  NaN         NaN
# 1                                                  NaN         6.9
# 2                                                  NaN         NaN
# 3                                                  NaN         9.0
# 4                                                  NaN         5.7
# ..                                                 ...         ...
# 852  Won 1 Golden Globe. Another 24 wins & 70 nomin...         8.3
# 853                                                NaN         5.8
# 854  Won 1 Golden Globe. Another 3 wins & 3 nominat...         8.8
# 855  Nominated for 3 Oscars. Another 1 win & 4 nomi...         7.2
# 856                                                NaN         5.6
#
#     release_date
# 0            NaN
# 1    07 Dec 1997
# 2            NaN
# 3    11 May 2004
# 4    28 May 1989
# ..           ...
# 852  31 Jan 1988
# 853  22 Dec 1961
# 854  16 Sep 1987
# 855  02 Apr 1958
# 856  27 Mar 1989
#
# [857 rows x 14 columns]

# %% [markdown]
# ### Remarks on the directors for TV shows
#
# For some tvseries, which do not have the episode information in the US DoD document, we have used the tvseries IMDB ID instead of episode IMDB ID. Thus, the OMDB API did not return a director name as there can be multiple directors to the series. Nevertheless, some series have only director. Such information can be found at [source](https://datasets.imdbws.com/), specifically [crew_dataset](title.crew.tsv.gz) and [name_dataset](name.basics.tsv.gz).
#
# Below, the directors name where there is no ambiguity is filled. We defined the ambiguous directors for the TV shows if there is more than one director ids are presented. Hence, we will only replace the directors' names where there is only one director id available.

# %%
# Source: https://datasets.imdbws.com/

# read the datasets
names = pd.read_csv('./../primary_data/imdb_data/name.basics.tsv.gz', compression='gzip', header=0, sep='\t')
crews = pd.read_csv('./../primary_data/imdb_data/title.crew.tsv.gz', compression='gzip', header=0, sep='\t')

# %%
# join the dod_movies_with_addl_data created above with crews dataset for directors informations 
dod_movies_with_addl_data_with_directors = pd.merge(dod_movies_with_addl_data, 
                                                    crews[['tconst', 'directors']], 
                                                    how ='left', 
                                                    left_on='IMDB_ID', 
                                                    right_on='tconst').drop('tconst', axis=1)

# In directors column from crews dataset, the NaN values are represented with '\N', so we should replace it with NaN 
directors_dict_clean = {'\\N': np.NaN}
dod_movies_with_addl_data_with_directors.directors.replace(directors_dict_clean, inplace=True)


# create a dictionary with director names and their ids
dict_director = names[['nconst', 'primaryName']].set_index('nconst').to_dict()['primaryName']
dod_movies_with_addl_data_with_directors
# Out:
#                              Title     IMDB_ID       Subtitle Status  \
# 0                           "1968"  Never Made            NaN    OTH
# 1             1,000 MEN AND A BABY   tt0133231            NaN    APP
# 2                        1ST FORCE  Never Made            NaN    OTH
# 3                               24   tt0502209             22    APP
# 4                       3RD DEGREE   tt0098469            NaN    APP
# ..                             ...         ...            ...    ...
# 852              WONDER YEARS, THE   tt0094582          ANGEL    LIM
# 853                           X-15   tt0055627            NaN    APP
# 854            YEAR IN THE LIFE, A   tt0092488  ACTS OF FAITH    DEN
# 855               YOUNG LIONS, THE   tt0052415            NaN    APP
# 856  YOUR MOMMA WEARS COMBAT BOOTS   tt0098696            NaN    APP
#
#     Media Type                                            Remarks  Year  \
# 0         FILM  THE FILM STARTED OUT VERY NEGATIVE FOR THE ARM...   NaN
# 1           TV  VERY POSITIVE DEPICTION OF NAVY IN THIS KOREAN...  1997
# 2         FILM  INITIALLY DOD AND USMC WERE INCLINED TO SUPPOR...   NaN
# 3           TV  APPROVED FILMING FOR ONE DAY WITH TWO MARINE C...  2004
# 4           TV  PERSONNEL APPEARED ON THIS GAME SHOW AT THE EX...  1989
# ..         ...                                                ...   ...
# 852         TV  THE UNITED STATES AIR FORCE GRANTED STOCK FOOT...  1988
# 853       FILM  AIRFORCE AND NASA PROVIDED FULL COOPERATION ON...  1961
# 854         TV                 THE PROJECT WAS DENIED ASSISTANCE.  1987
# 855       FILM  PENTAGON AND STATE DEPARTMENT WENT THROUGH LON...  1958
# 856         TV  ARMY AND AIR FORCE ASSISTANCE WAS GRANTED. THE...  1989
#
#                               genre  runtime               director  \
# 0                               NaN      NaN                    NaN
# 1                             Drama   96 min            Marcus Cole
# 2                               NaN      NaN                    NaN
# 3    Action, Crime, Drama, Thriller   42 min  Frederick King Keller
# 4            Crime, Drama, Thriller  100 min     Roger Spottiswoode
# ..                              ...      ...                    ...
# 852  Comedy, Drama, Family, Romance   22 min                    NaN
# 853                  Drama, History  107 min         Richard Donner
# 854                           Drama   60 min                    NaN
# 855              Action, Drama, War  167 min         Edward Dmytryk
# 856                          Comedy  100 min         Anson Williams
#
#                                                   plot  \
# 0                                                  NaN
# 1    A baby in a foreign land is adopted by the men...
# 2                                                  NaN
# 3    Jack and Tony clash as they wait for the time ...
# 4    Scott Weston is a private investigator who is ...
# ..                                                 ...
# 852  An adult Kevin Arnold reminisces on his teenag...
# 853  At the height of the Cold War during the 1960s...
# 854  Joe Gardner, a child of the Depression, is a s...
# 855  The destiny of three soldiers during World War...
# 856  An overprotective single mother tries to stop ...
#
#                                                  award imdb_rating  \
# 0                                                  NaN         NaN
# 1                                                  NaN         6.9
# 2                                                  NaN         NaN
# 3                                                  NaN         9.0
# 4                                                  NaN         5.7
# ..                                                 ...         ...
# 852  Won 1 Golden Globe. Another 24 wins & 70 nomin...         8.3
# 853                                                NaN         5.8
# 854  Won 1 Golden Globe. Another 3 wins & 3 nominat...         8.8
# 855  Nominated for 3 Oscars. Another 1 win & 4 nomi...         7.2
# 856                                                NaN         5.6
#
#     release_date                                          directors
# 0            NaN                                                NaN
# 1    07 Dec 1997                                          nm0170680
# 2            NaN                                                NaN
# 3    11 May 2004                                          nm0445631
# 4    28 May 1989                                          nm0006854
# ..           ...                                                ...
# 852  31 Jan 1988  nm0085209,nm0601963,nm0066439,nm0227781,nm0440...
# 853  22 Dec 1961                                          nm0001149
# 854  16 Sep 1987  nm0372133,nm0722493,nm0393661,nm0881306,nm0064...
# 855  02 Apr 1958                                          nm0229424
# 856  27 Mar 1989                                          nm0930041
#
# [857 rows x 15 columns]

# %%
# check only if director is NaN but directors includes one director id for corresponding movie
dod_movies_with_addl_data_with_directors.loc[(dod_movies_with_addl_data_with_directors.director.isna()) & (dod_movies_with_addl_data_with_directors.directors.notna())]
# Out:
#                                            Title    IMDB_ID  \
# 145                                  CHINA BEACH  tt0094433
# 156                                       CODE 3  tt0050005
# 217                           DIRT WATER DYNASTY  tt0095020
# 254                              FAMILY OF SPIES  tt0099543
# 256                                 FATAL VISION  tt0087244
# 267                         FINDER OF LOST LOVES  tt0086712
# 313                            GEORGE WASHINGTON  tt0086720
# 408                                          JAG  tt0112022
# 462               KENNEDYS OF MASSACHUSETTS, THE  tt0098838
# 486                                     M*A*S*H*  tt0068098
# 505                               MEDAL OF HONOR  tt0468427
# 520                           MISSION IMPOSSIBLE  tt0060009
# 528                         N.A.S. EMERALD POINT  tt0085012
# 549                                       NIKITA  tt1592154
# 567                              PANDORA'S CLOCK  tt0115309
# 638                            REAGAN YEARS, THE  tt6349394
# 649  ROBERT KENNEDY AND HIS TIMES (PART 1 AND 2)  tt0088594
# 669                           SEPARATE BUT EQUAL  tt0102879
# 678                              SIMON AND SIMON  tt0081930
# 682                                        SPACE  tt0088611
# 684                                   STAND, THE  tt0108941
# 688                                STARGATE SG-1  tt0118480
# 827            WAR AND REMEMBRANCE (MINI SERIES)  tt0096725
# 845                        WINDMILLS OF THE GODS  tt0096447
# 852                            WONDER YEARS, THE  tt0094582
# 854                          YEAR IN THE LIFE, A  tt0092488
#
#                                               Subtitle Status Media Type  \
# 145                                                NaN    DEN         TV
# 156  PILOT FOR NEW TV SERIES BASED ON "COPS" CONCEP...    APP         TV
# 217                                                NaN    LIM         TV
# 254                                                NaN    LIM         TV
# 256                                                NaN    OTH         TV
# 267                                                NaN    LIM         TV
# 313                                                NaN    APP         TV
# 408                                                NaN    DEN         TV
# 462                                                NaN    APP         TV
# 486                                                NaN    OTH         TV
# 505                                                NaN    APP         TV
# 520                                                NaN    APP         TV
# 528                                            HARPOON    APP         TV
# 549  AKA 'GIRL #5' ENGLISH VERSION OF FRENCH "LA FE...    DEN       FILM
# 567                                                NaN    DEN         TV
# 638                                                NaN    APP         TV
# 649                                                NaN    APP         TV
# 669                                                NaN    APP         TV
# 678                                                NaN    LIM         TV
# 682                                                NaN    APP         TV
# 684                                                NaN    DEN         TV
# 688                                     TITLE SEQUENCE    APP         TV
# 827                         SEQUEL TO THE WINDS OF WAR    APP         TV
# 845                                                NaN    OTH         TV
# 852                                              ANGEL    LIM         TV
# 854                                      ACTS OF FAITH    DEN         TV
#
#                                                Remarks  Year  \
# 145  DOD CONCLUDED THAT THE SERIES DID NOT PORTRAY ...  1988
# 156  CONCURRED WITH USARPAC/ARMY RECOMMENDATION TO ...  1957
# 217  THE DEPARTMENT APPROVED USE STOCK FOOTAGE TO T...  1988
# 254  THE REQUEST FOR EQUIPMENT AND FILMING ON SHIPS...  1990
# 256  THE FILM WAS QUITE ACCURATE AND FACTUAL. ALL T...  1984
# 267  THE DEPARTMENT FELT THE SCRIPT WOULD BE ADVANT...  1985
# 313  THE DOD APPROVED USE OF FORT BELVOIR FOR FILMI...  1984
# 408  QUESTIONABLE WHETHER OR NOT PRODUCTION COMPANY...  1995
# 462  THE PRODUCTION WAS GRANTED ITS REQUEST, PROVID...  1990
# 486  NOW CLASSIC TALE OF DOCTORS IN KOREAN WAR FIEL...  1972
# 505  ALL THE SERVICES AND THE DEPARTMENT APPROVED T...  2000
# 520  DOD SUPPORTED THE US OF MARCH AFB, A ONE-SHIP ...  1966
# 528  NAVY AND DOD FELT THE SCRIPT WAS BE ADVANTAGEO...  1983
# 549  DECLINED REQUEST TO USE MILITARY AIRCRAFT TO D...  2010
# 567  PRODUCTION COMPANY REQUESTED USE OF AIR FORCE ...  1996
# 638  APPROVED PROVIDING THE PRODUCTION FORWARDS A L...  1992
# 649  INITIALLY, FILMMAKERS DID NOT APPROACH MILITAR...  1985
# 669  THE ARMY ALLOWED USE OF WALTER REED ARMY HOSPI...  1991
# 678  DOD FOUND NOTHING OBJECTIONABLE ABOUT THE SCRI...  1981
# 682  APPROVED AND TO THE BEST INTEREST OF ALL THE S...  1985
# 684  REQUESTED USE OF MILITARY EQUIPMENT AND INSTAL...  1994
# 688  PRODUCTION COMPANY REQUESTED TO FILM EXTERIOR ...  1997
# 827  APPROVED IN THE BEST INTEREST OF THE DEPARTMEN...  1988
# 845     NO DOD ASSISTANCE WAS REQUIRED FOR THE SCRIPT.  1988
# 852  THE UNITED STATES AIR FORCE GRANTED STOCK FOOT...  1988
# 854                 THE PROJECT WAS DENIED ASSISTANCE.  1987
#
#                                                 genre    runtime director  \
# 145                               Drama, History, War    120 min      NaN
# 156                                      Crime, Drama     30 min      NaN
# 217                                             Drama    100 min      NaN
# 254                                             Drama    175 min      NaN
# 256                   Crime, Drama, History, Thriller    181 min      NaN
# 267                                             Drama     60 min      NaN
# 313                    Biography, Drama, History, War    480 min      NaN
# 408           Action, Crime, Drama, Mystery, Thriller     60 min      NaN
# 462                                             Drama    278 min      NaN
# 486                                Comedy, Drama, War     25 min      NaN
# 505  Action, Biography, Drama, History, Thriller, War     60 min      NaN
# 520         Action, Adventure, Crime, Drama, Thriller     50 min      NaN
# 528                                             Drama     60 min      NaN
# 549           Action, Crime, Drama, Mystery, Thriller     60 min      NaN
# 567                           Action, Drama, Thriller    176 min      NaN
# 638                                               NaN        NaN      NaN
# 649                                             Drama    309 min      NaN
# 669                                    Drama, History    190 min      NaN
# 678                     Action, Crime, Drama, Mystery     60 min      NaN
# 682                                             Drama    780 min      NaN
# 684         Adventure, Drama, Fantasy, Horror, Sci-Fi    361 min      NaN
# 688                  Action, Adventure, Drama, Sci-Fi     44 min      NaN
# 827                                        Drama, War  1,620 min      NaN
# 845                                   Drama, Thriller    187 min      NaN
# 852                    Comedy, Drama, Family, Romance     22 min      NaN
# 854                                             Drama     60 min      NaN
#
#                                                   plot  \
# 145  Dateline: November 1967, within klicks of Dana...
# 156  Code 3 is an American crime drama that aired i...
# 217  "Dirtwater Dynasty" is the story of embittered...
# 254  Park any subtlety at the threshold. The spits ...
# 256  In 1970, military doctor Jeffrey McDonald repo...
# 267  Cary Maxwell is a private investigator and own...
# 313  The early life and career of the American Gene...
# 408  Commander Harmon Rabb, Jr. and Lieutenant Colo...
# 462  This sweeping mini-series profiling the Kenned...
# 486  The 4077th Mobile Army Surgical Hospital is st...
# 505  Hosted by Academy Award nominee Burt Reynolds ...
# 520  Jim Phelps is the head of a super-secret gover...
# 528  The story took place on a naval base and dealt...
# 549  When she was a deeply troubled teenager, Nikit...
# 567  Quantum Airlines flight 66 has just taken off ...
# 638                                                NaN
# 649  A personal portrait of one of the most controv...
# 669  This film follows the true story of the NAACP ...
# 678  A.J. Simon is a polished fellow with a taste f...
# 682  A 13-hour mini-series detailing James A. Michn...
# 684  When a government-run lab accidentally lets lo...
# 688  General Hammond summons Colonel Jack O'Neill o...
# 827  The saga of the Henry family, begun in "The Wi...
# 845  When Mary Ashley is approached to become ambas...
# 852  An adult Kevin Arnold reminisces on his teenag...
# 854  Joe Gardner, a child of the Depression, is a s...
#
#                                                  award imdb_rating  \
# 145  Won 1 Golden Globe. Another 25 wins & 46 nomin...         8.2
# 156                                                NaN         7.5
# 217                                     2 nominations.         8.3
# 254  Nominated for 2 Golden Globes. Another 1 win &...         6.5
# 256  Won 1 Primetime Emmy. Another 2 wins & 8 nomin...         7.8
# 267                                                NaN         6.7
# 313                                                NaN         7.9
# 408  Won 3 Primetime Emmys. Another 9 wins & 17 nom...         6.6
# 462  Won 1 Golden Globe. Another 2 wins & 9 nominat...         7.0
# 486  Won 8 Golden Globes. Another 53 wins & 153 nom...         8.4
# 505                                                NaN         7.9
# 520  Won 3 Golden Globes. Another 16 wins & 39 nomi...         7.9
# 528                                                NaN         7.2
# 549  Nominated for 2 Primetime Emmys. Another 2 win...         7.7
# 567                                     2 nominations.         6.2
# 638                                                NaN         NaN
# 649                                                NaN         7.6
# 669  Nominated for 3 Golden Globes. Another 3 wins ...         7.4
# 678  Nominated for 2 Primetime Emmys. Another 4 nom...         7.1
# 682       Won 1 Primetime Emmy. Another 3 nominations.         7.3
# 684  Won 2 Primetime Emmys. Another 1 win & 7 nomin...         7.2
# 688  Nominated for 9 Primetime Emmys. Another 18 wi...         8.4
# 827  Won 3 Golden Globes. Another 9 wins & 19 nomin...         8.3
# 845                                      1 nomination.         6.2
# 852  Won 1 Golden Globe. Another 24 wins & 70 nomin...         8.3
# 854  Won 1 Golden Globe. Another 3 wins & 3 nominat...         8.8
#
#     release_date                                          directors
# 145  26 Apr 1988  nm0001460,nm0949722,nm0500609,nm0294350,nm0314...
# 156  02 Apr 1957  nm0004573,nm0905729,nm0324013,nm0190096,nm0524...
# 217  10 Apr 1988                                nm0420924,nm0694411
# 254  04 Feb 1990                                          nm0350455
# 256  18 Nov 1984                                          nm0338719
# 267  22 Sep 1984  nm0113617,nm0082676,nm0681604,nm0676336,nm0494...
# 313  08 Apr 1984                                          nm0474539
# 408  23 Sep 1995  nm0426687,nm0004895,nm0181445,nm0621137,nm0844...
# 462  18 Feb 1990                                          nm0425593
# 486  17 Sep 1972  nm0239291,nm0000257,nm0582401,nm0721728,nm0002...
# 505  11 Oct 2000                                nm0204920,nm0202835
# 520  17 Sep 1966  nm0046172,nm0186305,nm0469957,nm0441914,nm0394...
# 528  26 Sep 1983  nm0065568,nm0253605,nm0784388,nm0666274,nm0004...
# 549  09 Sep 2010  nm0514546,nm0277830,nm0178944,nm0402493,nm0733...
# 567  10 Nov 1996                                          nm0485637
# 638          NaN                                          nm0244620
# 649  27 Jan 1985                                          nm0159007
# 669  07 Apr 1991                                          nm0828211
# 678  24 Nov 1981  nm0918659,nm0129135,nm0128434,nm0342031,nm0082...
# 682  14 Apr 1985                                nm0680097,nm0765121
# 684  08 May 1994                                          nm0308376
# 688  27 Jul 1997  nm0217938,nm0939869,nm0586539,nm0912272,nm0314...
# 827  13 Nov 1988                                          nm0193303
# 845  07 Feb 1988                                          nm0680097
# 852  31 Jan 1988  nm0085209,nm0601963,nm0066439,nm0227781,nm0440...
# 854  16 Sep 1987  nm0372133,nm0722493,nm0393661,nm0881306,nm0064...

# %% [markdown]
# We see that for the IMDB_IDs _tt0099543, tt0087244, tt0086720, tt0098838, tt0115309, tt6349394, tt0088594, tt0102879, tt0108941, tt0096725, and tt0096447,_ we have exactly one corresponding director ids which we can match it with director name without any ambiguity.

# %%
imdb_ids_for_one_director_id = ['tt0099543', 'tt0087244', 'tt0086720', 'tt0098838', 'tt0115309', 'tt6349394', 'tt0088594', 'tt0102879', 'tt0108941', 'tt0096725', 'tt0096447']
dod_movies_with_addl_data_with_directors.loc[(dod_movies_with_addl_data_with_directors.director.isna()) & (dod_movies_with_addl_data_with_directors.directors.notna()) & (dod_movies_with_addl_data_with_directors.IMDB_ID.isin(imdb_ids_for_one_director_id))]
# Out:
#                                            Title    IMDB_ID  \
# 254                              FAMILY OF SPIES  tt0099543
# 256                                 FATAL VISION  tt0087244
# 313                            GEORGE WASHINGTON  tt0086720
# 462               KENNEDYS OF MASSACHUSETTS, THE  tt0098838
# 567                              PANDORA'S CLOCK  tt0115309
# 638                            REAGAN YEARS, THE  tt6349394
# 649  ROBERT KENNEDY AND HIS TIMES (PART 1 AND 2)  tt0088594
# 669                           SEPARATE BUT EQUAL  tt0102879
# 684                                   STAND, THE  tt0108941
# 827            WAR AND REMEMBRANCE (MINI SERIES)  tt0096725
# 845                        WINDMILLS OF THE GODS  tt0096447
#
#                        Subtitle Status Media Type  \
# 254                         NaN    LIM         TV
# 256                         NaN    OTH         TV
# 313                         NaN    APP         TV
# 462                         NaN    APP         TV
# 567                         NaN    DEN         TV
# 638                         NaN    APP         TV
# 649                         NaN    APP         TV
# 669                         NaN    APP         TV
# 684                         NaN    DEN         TV
# 827  SEQUEL TO THE WINDS OF WAR    APP         TV
# 845                         NaN    OTH         TV
#
#                                                Remarks  Year  \
# 254  THE REQUEST FOR EQUIPMENT AND FILMING ON SHIPS...  1990
# 256  THE FILM WAS QUITE ACCURATE AND FACTUAL. ALL T...  1984
# 313  THE DOD APPROVED USE OF FORT BELVOIR FOR FILMI...  1984
# 462  THE PRODUCTION WAS GRANTED ITS REQUEST, PROVID...  1990
# 567  PRODUCTION COMPANY REQUESTED USE OF AIR FORCE ...  1996
# 638  APPROVED PROVIDING THE PRODUCTION FORWARDS A L...  1992
# 649  INITIALLY, FILMMAKERS DID NOT APPROACH MILITAR...  1985
# 669  THE ARMY ALLOWED USE OF WALTER REED ARMY HOSPI...  1991
# 684  REQUESTED USE OF MILITARY EQUIPMENT AND INSTAL...  1994
# 827  APPROVED IN THE BEST INTEREST OF THE DEPARTMEN...  1988
# 845     NO DOD ASSISTANCE WAS REQUIRED FOR THE SCRIPT.  1988
#
#                                          genre    runtime director  \
# 254                                      Drama    175 min      NaN
# 256            Crime, Drama, History, Thriller    181 min      NaN
# 313             Biography, Drama, History, War    480 min      NaN
# 462                                      Drama    278 min      NaN
# 567                    Action, Drama, Thriller    176 min      NaN
# 638                                        NaN        NaN      NaN
# 649                                      Drama    309 min      NaN
# 669                             Drama, History    190 min      NaN
# 684  Adventure, Drama, Fantasy, Horror, Sci-Fi    361 min      NaN
# 827                                 Drama, War  1,620 min      NaN
# 845                            Drama, Thriller    187 min      NaN
#
#                                                   plot  \
# 254  Park any subtlety at the threshold. The spits ...
# 256  In 1970, military doctor Jeffrey McDonald repo...
# 313  The early life and career of the American Gene...
# 462  This sweeping mini-series profiling the Kenned...
# 567  Quantum Airlines flight 66 has just taken off ...
# 638                                                NaN
# 649  A personal portrait of one of the most controv...
# 669  This film follows the true story of the NAACP ...
# 684  When a government-run lab accidentally lets lo...
# 827  The saga of the Henry family, begun in "The Wi...
# 845  When Mary Ashley is approached to become ambas...
#
#                                                  award imdb_rating  \
# 254  Nominated for 2 Golden Globes. Another 1 win &...         6.5
# 256  Won 1 Primetime Emmy. Another 2 wins & 8 nomin...         7.8
# 313                                                NaN         7.9
# 462  Won 1 Golden Globe. Another 2 wins & 9 nominat...         7.0
# 567                                     2 nominations.         6.2
# 638                                                NaN         NaN
# 649                                                NaN         7.6
# 669  Nominated for 3 Golden Globes. Another 3 wins ...         7.4
# 684  Won 2 Primetime Emmys. Another 1 win & 7 nomin...         7.2
# 827  Won 3 Golden Globes. Another 9 wins & 19 nomin...         8.3
# 845                                      1 nomination.         6.2
#
#     release_date  directors
# 254  04 Feb 1990  nm0350455
# 256  18 Nov 1984  nm0338719
# 313  08 Apr 1984  nm0474539
# 462  18 Feb 1990  nm0425593
# 567  10 Nov 1996  nm0485637
# 638          NaN  nm0244620
# 649  27 Jan 1985  nm0159007
# 669  07 Apr 1991  nm0828211
# 684  08 May 1994  nm0308376
# 827  13 Nov 1988  nm0193303
# 845  07 Feb 1988  nm0680097

# %%
one_director_id = dod_movies_with_addl_data_with_directors.loc[(dod_movies_with_addl_data_with_directors.director.isna()) & (dod_movies_with_addl_data_with_directors.directors.notna()) & (dod_movies_with_addl_data_with_directors.IMDB_ID.isin(imdb_ids_for_one_director_id))].directors.to_list()
one_director_id
# Out:
# ['nm0350455',
#  'nm0338719',
#  'nm0474539',
#  'nm0425593',
#  'nm0485637',
#  'nm0244620',
#  'nm0159007',
#  'nm0828211',
#  'nm0308376',
#  'nm0193303',
#  'nm0680097']

# %%
for index, data in enumerate(one_director_id):
    for key, value in dict_director.items():
        if key in data:
            one_director_id[index]=data.replace(key, dict_director[key])

# %%
one_director_id
# Out:
# ['Stephen Gyllenhaal',
#  'David Greene',
#  'Buzz Kulik',
#  'Lamont Johnson',
#  'Eric Laneuville',
#  'Phil Dusenberry',
#  'Marvin J. Chomsky',
#  'George Stevens Jr.',
#  'Mick Garris',
#  'Dan Curtis',
#  'Lee Philips']

# %%
interested_indexes = dod_movies_with_addl_data_with_directors.loc[(dod_movies_with_addl_data_with_directors.director.isna()) & (dod_movies_with_addl_data_with_directors.directors.notna()) & (dod_movies_with_addl_data_with_directors.IMDB_ID.isin(imdb_ids_for_one_director_id))].index

# %%
# assign the director names found above to the corresponding director id
for i in range(len(one_director_id)):
    dod_movies_with_addl_data_with_directors.loc[interested_indexes[i],'director'] = one_director_id[i]

# %% [markdown]
# # Saving the Data
#
# Since we would require this data frame in the analysis further we shall store it on the harddrive. We will store both a csv file and a binary pickle file. The CSV file will be used as human readable format while pickle file will be useful to quick reading.

# %%
dod_movies_with_addl_data_with_directors.to_csv("./../with_additional_data/military_hollywood_with_additional_data.csv", index=False)
dod_movies_with_addl_data_with_directors.to_pickle("./../with_additional_data/military_hollywood_with_additional_data.pkl")
